# %% [markdown]
# # AgriSmart AI - Model Training Pipeline (Colab)
# Run this notebook in Google Colab with a GPU runtime to train the model quickly.

# %%
# !git clone https://github.com/MeetBhavsar2701/Hackinators_Agrismart_AI.git
# %cd Hackinators_Agrismart_AI
# !git checkout feature/model-training

# %%
# !pip install -r requirements.txt

# %% [markdown]
# ### Dataset Download
# Ensure you upload or download the `PlantVillage` and `PlantDoc` datasets into the `data/` folder before proceeding.

# %%
# !python model/prepare_data.py

# %%
# Train for 50 epochs on GPU
# !python model/train.py --epochs 50 --batch_size 32

# %%
# Evaluate and generate confusion matrix
# !python model/evaluate.py

# %%
# Calibrate model with temperature scaling
# !python model/calibrate.py
